# %%
import torch
from scipy.io import loadmat

# %%
path = 'Pitts30K_struct.mat'
mat = loadmat(path)

# %%
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue Jun  8 12:35:34 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'net': array([[(array([[array([[(array([[array([[[[ 4.80015397e-01, -1.72696680e-01,  3.75577137e-02, ...,
#                                            -1.27135560e-01, -5.02991639e-02,  3.48965675e-02],
#                                           [ 5.50379455e-01,  2.08774377e-02,  9.88311544e-02, ...,
#                                            -8.48205537e-02, -5.11389151e-02,  3.74943428e-02],
#                                           [ 4.29470569e-01,  1.17273867e-01,  3.40129584e-02, ...,
#                                            -1.32241577e-01, -5.33475243e-02,  7.57738389e-03]],
#
#                                          [[ 4.08547401e-01, -1.70375049e-01, -4.96297423e-03, ...,
#                                            -1.22360572e-01, -2.76450396e-01, -3.90796512e-02],
# ...
